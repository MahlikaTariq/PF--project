# %% [markdown]
# Name : Mahlika
#
#
# Roll No:SU92-BSAIM-F24-059
#
#
# Programming Fundamental Project

# %%
import pandas as pd

# %%
df = pd.read_csv('project.csv')

# %%
df
# Out:
#       RowNumber  CustomerId     Surname  CreditScore Geography  Gender  Age  \
# 0             1    15598695      Fields          619    France  Female   42
# 1             2    15649354    Johnston          608     Spain  Female   41
# 2             3    15737556    Vasilyev          502    France  Female   42
# 3             4    15671610      Hooper          699    France  Female   39
# 4             5    15625092     Colombo          850     Spain  Female   43
# ...         ...         ...         ...          ...       ...     ...  ...
# 9995       9996    15583480      Morgan          771    France    Male   39
# 9996       9997    15620341     Nwebube          516    France    Male   35
# 9997       9998    15613886    Trevisan          709    France  Female   36
# 9998       9999    15792916  Ositadimma          772   Germany    Male   42
# 9999      10000    15710408  Cunningham          792    France  Female   28
#
# ...

# %%
df.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15598695    Fields          619    France  Female   42
# 1          2    15649354  Johnston          608     Spain  Female   41
# 2          3    15737556  Vasilyev          502    France  Female   42
# 3          4    15671610    Hooper          699    France  Female   39
# 4          5    15625092   Colombo          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited  Complain  Satisfaction Score Card Type  \
# 0        101348.88       1         1                   2   DIAMOND
# ...

# %%
df.tail()
# Out:
#       RowNumber  CustomerId     Surname  CreditScore Geography  Gender  Age  \
# 9995       9996    15583480      Morgan          771    France    Male   39
# 9996       9997    15620341     Nwebube          516    France    Male   35
# 9997       9998    15613886    Trevisan          709    France  Female   36
# 9998       9999    15792916  Ositadimma          772   Germany    Male   42
# 9999      10000    15710408  Cunningham          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 9995       5       0.00              2          1               0
# 9996      10   57369.61              1          1               1
# 9997       7       0.00              1          0               1
# 9998       3   75075.31              2          1               0
# 9999       4  130142.79              1          1               0
#
#       EstimatedSalary  Exited  Complain  Satisfaction Score Card Type  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 18 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   RowNumber           10000 non-null  int64
#  1   CustomerId          10000 non-null  int64
#  2   Surname             10000 non-null  object
#  3   CreditScore         10000 non-null  int64
#  4   Geography           10000 non-null  object
#  5   Gender              10000 non-null  object
#  6   Age                 10000 non-null  int64
#  7   Tenure              10000 non-null  int64
#  8   Balance             10000 non-null  float64
#  9   NumOfProducts       10000 non-null  int64
#  10  HasCrCard           10000 non-null  int64
#  11  IsActiveMember      10000 non-null  int64
#  12  EstimatedSalary     10000 non-null  float64
#  13  Exited              10000 non-null  int64
#  14  Complain            10000 non-null  int64
# ...

# %%
df.sample(6)
# Out:
#       RowNumber  CustomerId          Surname  CreditScore Geography  Gender  \
# 8564       8565    15803121             Chia          519    France    Male
# 5553       5554    15709324            Bruce          666   Germany    Male
# 3502       3503    15574858             Page          735   Germany    Male
# 9348       9349    15579387               Ni          664    France  Female
# 2631       2632    15793896             John          629    France    Male
# 9347       9348    15645271  Radcliffe-Brown          660     Spain  Female
#
#       Age  Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 8564   48      10   71083.98              1          1               0
# 5553   31       3  123212.08              2          1               1
# 3502   46       2  106344.95              1          1               0
# 9348   34       7   93920.47              1          0               0
# 2631   35       1  172170.36              1          1               1
# ...

# %%
df.describe()
# Out:
#          RowNumber    CustomerId   CreditScore           Age        Tenure  \
# count  10000.00000  1.000000e+04  10000.000000  10000.000000  10000.000000
# mean    5000.50000  1.569094e+07    650.528800     38.921800      5.012800
# std     2886.89568  7.193619e+04     96.653299     10.487806      2.892174
# min        1.00000  1.556570e+07    350.000000     18.000000      0.000000
# 25%     2500.75000  1.562853e+07    584.000000     32.000000      3.000000
# 50%     5000.50000  1.569074e+07    652.000000     37.000000      5.000000
# 75%     7500.25000  1.575323e+07    718.000000     44.000000      7.000000
# max    10000.00000  1.581569e+07    850.000000     92.000000     10.000000
#
#              Balance  NumOfProducts    HasCrCard  IsActiveMember  \
# count   10000.000000   10000.000000  10000.00000    10000.000000
# mean    76485.889288       1.530200      0.70550        0.515100
# std     62397.405202       0.581654      0.45584        0.499797
# ...

# %%
df.describe(include="all")
# Out:
#           RowNumber    CustomerId Surname   CreditScore Geography Gender  \
# count   10000.00000  1.000000e+04   10000  10000.000000     10000  10000
# unique          NaN           NaN    2932           NaN         3      2
# top             NaN           NaN   Smith           NaN    France   Male
# freq            NaN           NaN      32           NaN      5014   5457
# mean     5000.50000  1.569094e+07     NaN    650.528800       NaN    NaN
# std      2886.89568  7.193619e+04     NaN     96.653299       NaN    NaN
# min         1.00000  1.556570e+07     NaN    350.000000       NaN    NaN
# 25%      2500.75000  1.562853e+07     NaN    584.000000       NaN    NaN
# 50%      5000.50000  1.569074e+07     NaN    652.000000       NaN    NaN
# 75%      7500.25000  1.575323e+07     NaN    718.000000       NaN    NaN
# max     10000.00000  1.581569e+07     NaN    850.000000       NaN    NaN
#
#                  Age        Tenure        Balance  NumOfProducts    HasCrCard  \
# ...

# %%
df.drop_duplicates()
# Out:
#       RowNumber  CustomerId     Surname  CreditScore Geography  Gender  Age  \
# 0             1    15598695      Fields          619    France  Female   42
# 1             2    15649354    Johnston          608     Spain  Female   41
# 2             3    15737556    Vasilyev          502    France  Female   42
# 3             4    15671610      Hooper          699    France  Female   39
# 4             5    15625092     Colombo          850     Spain  Female   43
# ...         ...         ...         ...          ...       ...     ...  ...
# 9995       9996    15583480      Morgan          771    France    Male   39
# 9996       9997    15620341     Nwebube          516    France    Male   35
# 9997       9998    15613886    Trevisan          709    France  Female   36
# 9998       9999    15792916  Ositadimma          772   Germany    Male   42
# 9999      10000    15710408  Cunningham          792    France  Female   28
#
# ...

# %%
df["Age"].value_counts().plot(kind = "bar")
# Out:
# <Axes: xlabel='Age'>

# %%
df["Age"].value_counts().plot(kind = "density")
# Out:
# <Axes: ylabel='Density'>

# %%
df["Age"].value_counts().plot(kind = "kde")
# Out:
# <Axes: ylabel='Density'>

# %%
df["Age"].value_counts().plot(kind = "hist")
# Out:
# <Axes: ylabel='Frequency'>

# %%
df["Age"].value_counts().plot(kind = "box")
# Out:
# <Axes: >

# %%
df["Age"].value_counts().plot(kind = "pie")
# Out:
# <Axes: ylabel='count'>

# %%
df["Age"].value_counts().plot(kind = "line")
# Out:
# <Axes: xlabel='Age'>

# %%
mean_credit_score = df["CreditScore"].mean()
print("Mean Credit Score:", mean_credit_score)
# Out:
# Mean Credit Score: 650.5288

# %%
mean_points = df["Point Earned"].mean()
print("Mean Points Earned:", mean_points)
# Out:
# Mean Points Earned: 606.5151

# %%
mode_credit_score = df["CreditScore"].mode()[0]
print("Mode Credit Score:", mode_credit_score)
# Out:
# Mode Credit Score: 850

# %%
mode_points = df["Point Earned"].mode()[0]
print("Mode Points Earned:", mode_points)
# Out:
# Mode Points Earned: 408

# %%
df["CreditScore_Age_Sum"] = df["CreditScore"] + df["Age"]
print("Total sum of columns:", total_sum)
# Out:
# Total sum of columns: CreditScore     6505288
# Age              389218
# Point Earned    6065151
# dtype: int64

# %%
total_sum = df[["CreditScore", "Age", "Point Earned"]].sum()
print("Total sum of columns:", total_sum)
# Out:
# Total sum of columns: CreditScore     6505288
# Age              389218
# Point Earned    6065151
# dtype: int64
